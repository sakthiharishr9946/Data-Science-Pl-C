# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# #### Heading 4

# %% [markdown]
# ##### Heading 5

# %% [markdown]
# ###### Heading 6

# %% [markdown]
# # *Heading 7*

# %% [markdown]
# - Mithra
# - sakthi
# - Vishnu

# %% [markdown]
# name | course | mark

# %% [markdown]
# | name | course | mark |
# |-----|--------|-------|
# |Mithra | DS | 99.99|

# %% [markdown]
# ''' print("hiii")'''

# %%
# %time sum(range(100))
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 4950

# %%
# %pwd
# Out:
# 'C:\\Users\\harish\\Placement Session'

# %%
# %history
# Out:
# ##### Heading 5
# # *Heading 7*
# name | course | mark
# name | course | mark
# ''' print("hiii")'''
# %time sum(range(100))
# %history

# %%
# %who
# Out:
# Interactive namespace is empty.

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5043-1CBC
#
#  Directory of C:\Users\harish\Placement Session
#
# 29-05-2026  03:42 PM    <DIR>          .
# 29-05-2026  02:28 PM    <DIR>          ..
# 29-05-2026  02:48 PM    <DIR>          .ipynb_checkpoints
# 29-05-2026  03:42 PM             4,173 Jupyter Introduction.ipynb
#                1 File(s)          4,173 bytes
#                3 Dir(s)  33,120,108,544 bytes free

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
# %who
# Out:
# Interactive namespace is empty.

# %%
# %%writefile sample.py
print("hii")
# Out:
# Writing sample.py

# %%
# %run sample.py
# Out:
# hii
